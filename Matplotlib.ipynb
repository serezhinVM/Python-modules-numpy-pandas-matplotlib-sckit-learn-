# %%
# MATPLOTLIB
# pip install matplotlib
# pip install pyqt 5

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from datetime import datetime

# %%
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
fig = plt.gcf()
plt.show()
# plt.savefig('ttt.png')

# %%
from IPython.display import Image

# %%
# Image('ttt.png') - use $matplotlib widget

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
#img = mpimg.imread('ttt.png')
#plt.imshow(img)
#plt.axis('off') # скрыть оси
#plt.show()

# %%
#1 вариант рисования графиков:
# MATLAB's style
# Обозначил место нарисования - нарисовал. Новое место рисования - нарисовал: (2,1,1), (2,1,2)
x = np.linspace(0,10,100)
print(x[:5])

plt.subplot(2,1,1) # 2 string 1 columns
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

plt.show()
# Out:
# [0.        0.1010101 0.2020202 0.3030303 0.4040404]

# %%
print(plt.gcf()) # get current figure
print(plt.gca()) # get current axis
plt.close() # close the empty draw
# Out:
# Figure(640x480)
# Axes(0.125,0.11;0.775x0.77)

# %%
# 2 вариант рисования графиков
# OO (Объектно-ориентированный)
fig, ax = plt.subplots(2) # метод возвращает фигуру и оси

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

plt.show()

# %%
# OO and MATLAB styles give the same result
print(fig)
print(ax[0])
# Out:
# Figure(640x480)
# Axes(0.125,0.53;0.775x0.35)

# %%
x = np.linspace(0, 10, 1000)

ax = plt.gca()
ax.plot(x, np.sin(x),   color='blue',    linestyle='solid')   # full color name (salmon - лососевый)   # -
ax.plot(x, np.sin(x-1), color='g',       linestyle='dashed')  # single letter                          # --
ax.plot(x, np.sin(x-2), color='0.2'   ,  linestyle='dashdot') # grayscale (0=black, 1=white)          # -.
ax.plot(x, np.sin(x-3), color='#FFDDAA', linestyle='dotted')  # hex RGB triplet                        # :
ax.plot(x, np.sin(x-4), color=(1.0, 0.3, 0.3))                # RGB tuple (0–1)
ax.plot(x, np.sin(x-5), '--y')                                # mixed approach

ax.axis('equal')

plt.show()

# %%
fig, ax = plt.subplots(5)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.sin(x))
ax[2].plot(x, np.sin(x))
ax[3].plot(x, np.sin(x))
ax[4].plot(x, np.sin(x))

ax[1].set_xlim(-2, 12)
ax[1].set_ylim(-2, 2)

ax[2].set_xlim(12, -2) # задаёт границы по X. Если левый > правый, ось разворачивается.
ax[2].set_ylim(2, -2)  # mirroring the graph

#ax[3].axis('tight') # автоматический подбор 'лучшего' варианта
ax[3].autoscale(tight=True) # убирает все поля вокруг данных (границы осей = min и max данных)

ax[4].axis('equal') # делает масштаб осей одинаковым, что искажает внешний вид, но сохраняет геометрические пропорции.

plt.tight_layout() # графики не наезжают друг на друга (автоматически подбирается)

plt.show()

# %%
plt.subplot(3, 1, 1)
plt.plot(x, np.sin(x) * np.sqrt(2))
plt.title('Синус')
plt.xlabel('x')
plt.ylabel('$\sqrt{2}$ sin(x)') # support Latex

plt.subplot(3, 1, 2)
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.legend()
plt.title('Синус и косинус')

plt.subplot(3, 1, 3)
plt.plot(x, np.sin(x), '--k', label='$\sin x$')
plt.plot(x, np.cos(x), '-r',  label='$\cos x$' )
plt.legend()
plt.title('Синус и косинус 2')

plt.subplots_adjust(hspace=1) # or auto-version plt.tight_layout()

plt.show()
# Out:
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXGeneral'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXNonUnicode'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXSizeOneSym'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXSizeTwoSym'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXSizeThreeSym'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXSizeFourSym'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['STIXSizeFiveSym'] not found. Falling back to DejaVu Sans.
# ...

# %%
# Диаграмма рассеивания
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 
         'v',
         linestyle='--',
         color='black',
         markersize=15,
         markerfacecolor='red',
         markeredgecolor='blue',
         markeredgewidth=None,
         linewidth=None
        )

plt.show()

# %%
rng = np.random.default_rng(1)
colors = rng.random(30)
sizes = 100 * rng.random(30)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.4)

plt.colorbar()

plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)

print(iris.frame.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
plt.scatter(
    iris.frame['sepal length (cm)'],
    iris.frame['sepal width (cm)'],
    s = 20 * iris.frame['petal length (cm)'], # в размер точек заложим размер petal length (длину лепестка)
    c = iris.frame['target'], # в цвет точек заложим цвет лепестков 
    alpha = 0.3
)

plt.show()

# %%
rng = np.random.default_rng(1)
x = np.linspace(0, 10, 100)
dy = 0.5
y = np.sin(x) + dy * rng.random(100)

plt.plot(x,y, '--k')

plt.errorbar(x, y, yerr=dy, fmt='.g')

plt.fill_between(x, y - dy, y + dy, color='0.75', alpha=0.7)

plt.show()

# %%
# графики плотности и контурные графики (на 2D изобразить 3D)
x = np.linspace(0, 6, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y) # превращает одномерные массивы координат (x, y) в двумерные матрицы, которые вместе задают все точки прямоугольной сетки.
print(X, end='\n\n') # каждая строка повторяет массив x (40 строка на 50 столбцов)
print(Y) # каждый столбец повторяет массив y (40 на 50).

# Таким образом, пара (X[i, j], Y[i, j]) даёт координаты точки на пересечении j-го значения x и i-го значения y.
# Out:
# [[0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]
#  [0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]
#  [0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]
#  ...
#  [0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]
#  [0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]
#  [0.         0.12244898 0.24489796 ... 5.75510204 5.87755102 6.        ]]
#
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [0.12820513 0.12820513 0.12820513 ... 0.12820513 0.12820513 0.12820513]
#  [0.25641026 0.25641026 0.25641026 ... 0.25641026 0.25641026 0.25641026]
#  ...
#  [4.74358974 4.74358974 4.74358974 ... 4.74358974 4.74358974 4.74358974]
#  [4.87179487 4.87179487 4.87179487 ... 4.87179487 4.87179487 4.87179487]
#  [5.         5.         5.         ... 5.         5.         5.        ]]

# %%
def f(x, y):
    return np.sin(x) ** 4 + np.cos(y + x * 30) * np.sin(y)

Z = f(X, Y)

print(Z.shape)
# Out:
# (40, 50)

# %%
# plt.contour(X, Y, Z)
# plt.contour(X, Y, Z, colors='black')
# plt.contourf(X, Y, Z, 10, cmap='RdGy_r')
# plt.contourf(X, Y, Z, 10, cmap='RdGy_r')
# plt.contourf(X, Y, Z, 10, cmap='RdGy')
cnt = plt.contour(X, Y, Z, 10, colors='black', alpha=0.5)
plt.clabel(cnt, inline=True)

plt.colorbar()

plt.imshow(
    Z,
    extent=[0,6, 0,5],
    origin='lower',
    cmap='RdGy',
    interpolation='gaussian',
    aspect='equal',
    alpha=1
)

plt.show()

# %%
# Гистограммы
rng = np.random.default_rng(1)
data = rng.normal(size=1000)

plt.hist(data, bins=30, density=True)

plt.show()

# %%
rng = np.random.default_rng(1)
x1 = rng.normal(0, 0.8, 1000)
x2 = rng.normal(-2, 1, 1000)
x3 = rng.normal(3, 2, 1000)

p = dict(alpha=0.3, bins=40)

plt.hist(x1, **p)
plt.hist(x2, **p)
plt.hist(x3, **p)

plt.show()

# %%
print(np.histogram(x1, bins=40))
# Out:
# (array([ 1,  0,  1,  0,  4,  3,  4, 11,  5, 14, 18, 33, 35, 48, 44, 58, 63,
#        73, 64, 85, 81, 52, 60, 55, 68, 26, 25, 17, 12, 19,  6,  8,  1,  2,
#         1,  1,  1,  0,  0,  1], dtype=int64), array([-2.83904398, -2.69303518, -2.54702638, -2.40101758, -2.25500878,
#        -2.10899998, -1.96299118, -1.81698239, -1.67097359, -1.52496479,
#        -1.37895599, -1.23294719, -1.08693839, -0.94092959, -0.79492079,
#        -0.648912  , -0.5029032 , -0.3568944 , -0.2108856 , -0.0648768 ,
#         0.081132  ,  0.2271408 ,  0.3731496 ,  0.51915839,  0.66516719,
#         0.81117599,  0.95718479,  1.10319359,  1.24920239,  1.39521119,
#         1.54121999,  1.68722878,  1.83323758,  1.97924638,  2.12525518,
#         2.27126398,  2.41727278,  2.56328158,  2.70929038,  2.85529918,
#         3.00130797]))

# %%
mean = [0, 0]
cov = [[1,1], [1,3]]
x,y = rng.multivariate_normal(mean, cov, 10000).T

# plt.hist2d(x,y, bins=40)

plt.hexbin(x, y, gridsize=30)

plt.colorbar()

plt.show()

# %%
# Легенды
x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots()

ax.plot(x, np.sin(x), '-b', label='sin x')
ax.plot(x, np.cos(x), '--k', label='cos x')
ax.axis('equal')

ax.legend(frameon=True, shadow=True, borderpad=None, loc='upper right', ncol=2)

plt.show()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))

lines = plt.plot(x, y)

plt.legend(lines[:3], ['первая', 'вторая', 'третья', 'четвёртая'], loc = 'upper right') # the last one was ignored

plt.axis('equal')

plt.show()

# %%
plt.plot(x, y[:,0], label='первый')
plt.plot(x, y[:,1], label='второй')
plt.plot(x, y[:,2])

plt.legend(loc = 'upper right')

plt.axis('equal')

plt.show()

# %%
cities = pd.read_csv('california_cities.csv')
print(cities.head())
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
latd = cities['latd']
longd = cities['longd']
population_total = cities['population_total']
area_total_km2 = cities['area_total_km2']

# %%
plt.scatter(
    latd,
    longd,
    c=np.log10(population_total),
    s=area_total_km2,
    alpha=0.5
)

plt.scatter([], [], s=100, c='k', label='100 $km^2$', alpha=0.5)
plt.scatter([], [], s=300, c='k', label='300 $km^2$', alpha=0.5)
plt.scatter([], [], s=500, c='k', label='500 $km^2$', alpha=0.5)

plt.colorbar()
plt.axis('equal')
plt.legend(frameon = False, labelspacing=1.5, title='площадь') # легенды не залазают друг на друга
plt.show()

# %%
import matplotlib as mpl # we need it for adding legends

x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()

lines = ax.plot(x, np.sin(x[:, np.newaxis] - np.pi / 2 * np.arange(0, 4, 0.5)))

ax.axis('equal')

ax.legend(lines[:2], ['line A', 'line B'], loc='lower right')
leg = mpl.legend.Legend(ax, lines[2:], ['line C', 'line D'], loc='upper right')
ax.add_artist(leg) # We can show different legends

plt.show()

# %%
# Цветовые шкалы (colorbar)
x = np.linspace(0, 10, 1000)
y = np.sin(x) * np.cos(x[:, np.newaxis])

# Эти три схемы хорошо переводятся в чёрно-белый вариант
plt.imshow(y, cmap='jet')
#plt.imshow(y, cmap='viridis')
#plt.imshow(y, cmap='RdBu')


plt.colorbar()

plt.show()

# %%
# Дискретные шкалы
plt.imshow(y, cmap='Set1')

plt.colorbar()

plt.show()

# %%
from sklearn.datasets import load_digits

digits = load_digits(n_class=6)

fig, ax = plt.subplots(8, 8)
for i, ax_ in enumerate(ax.flat):
    ax_.imshow(digits.images[i], cmap='binary')
    ax_.set(xticks=[], yticks=[])

# %%
from sklearn.manifold import Isomap

iso = Isomap(n_components=2, n_neighbors=10)
prj = iso.fit_transform(digits.data)

plt.scatter(
    prj[:, 0],
    prj[:, 1],
    c=digits.target,
    cmap=plt.get_cmap('jet', 6)
)

plt.colorbar(ticks=range(6))
plt.clim(-0.5, 5.5)

plt.show()

# %%
# субграфики (MATLAB style)
x = np.linspace(0, 1, 20)

ax1 = plt.axes()
ax1.plot(np.sin(x))

# нижний, левый, ширина и высота прямоугольника
# 0.4 - 40% ширины рисунка, 0.3 - 30% высоты рисунка
ax2 = plt.axes([0.4, 0.3, 0.2, 0.1])
ax2.plot(np.cos(x))

plt.show()

# %%
# the same, but in OO style
fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax2 = fig.add_axes([0.4, 0.3, 0.2, 0.1])

ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])

ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

plt.show()

# %%
x = np.linspace(0, 10, 50)

fig = plt.figure()

for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.plot(x, np.sin(x + np.pi / 4 * i))

plt.tight_layout()

plt.show()

# %%
x1 = np.linspace(0, 10, 50)
x2 = np.linspace(0, 20, 50)


fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

for i in range(2):
    for j in range(3):
        if i % 2 == 0:
            ax[i, j].plot(x1, np.sin(x1 + np.pi / 4 * (i * 2 + j)))
        else:
            ax[i, j].plot(x2, np.sin(x2 + np.pi / 4 * (i * 2 + j)))

plt.tight_layout()

plt.show()

# %%
grid = plt.GridSpec(2, 3, wspace = 0.4, hspace = 0.2)
#   0 1 2
# 0 X Y K
# 1 Z Z K

plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1])
plt.subplot(grid[1, :2])
plt.subplot(grid[0:, 2])

#lt.tight_layout()

plt.show()

# %%
# %%capture
# Нормальное распределение
rng = np.random.default_rng(1)
x, y = rng.multivariate_normal([0, 0], [[1, 2], [3, 4]], 1000).T

# %%
grid = plt.GridSpec(4, 4)

# Y Z Z Z
# Y Z Z Z
# Y Z Z Z
#   X X X

main_axes = plt.subplot(grid[:3, 1:], yticklabels=[], xticklabels=[]) # Z
x_axes = plt.subplot(grid[-1, 1:])    # X
y_axes = plt.subplot(grid[:3, 0])     # Y

main_axes.scatter(x, y, c='k', alpha=0.2)

y_axes.hist(y, bins=40, orientation='horizontal', color='grey')
y_axes.invert_xaxis()

x_axes.hist(x, bins=40, orientation='vertical', color='grey')
x_axes.invert_yaxis()

plt.tight_layout()

plt.show()

# %%
# %%capture
'''
births = pd.read_csv('births.csv')

births.index = pd.to_datetime(births[['year', 'month', 'day']], format='%Y%m%d', errors='coerce')

births = births[births.index.notna()]   # ← фильтрация по индексу

print(births)
'''

# %%
# %%capture
'''
births_dom = births.pivot_table('births', index=[births.index.month, births.index.day])

def safe_date(month, day):
    try:
        return datetime(1969, month, day)
    except ValueError:
        return None

births_dom.index = [safe_date(month, day) for (month, day) in births_dom.index]
births_dom = births_dom.dropna()

print(births_dom)
'''

# %%
# %%capture
'''
fig, ax = plt.subplots()

births_dom.plot(ax=ax)

ax.text('1969-1-1', 5500, "New Year")

ax.xaxis.set_major_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%h'))

ax.annotate('Текст аннотации', xy=('1969-1-1', 5500), xytext=('1969-12-1', 4500), 
            arrowprops=dict(arrowstyle='->', facecolor='black', connectionstyle='angle3,angleA=0,angleB=45'))

plt.show()
'''

# %%
plt.figure()

ax1 = plt.axes()
ax2 = plt.axes([0.4, 0.3, 0.1, 0.2]) # создать вложенные оси с координатами (x, y, ширина, высота) в 

ax1.text(0.6, 0.8, '#1', transform=ax1.transData) # текст в системе координат данных ax1 (точка (0.6,0.8) в data)
ax2.text(0.6, 0.8, '#2', transform=ax2.transData) # аналогично для ax2, но координаты data свои для каждого

ax1.text(0.5, 0.1, '#1_2', transform=ax1.transAxes) # текст в относительных координатах осей ax1 (0..1 по ширине/высоте)
ax2.text(0.5, 0.1, '#2_2', transform=ax2.transAxes)

ax1.text(0.1, 0.1, '#1_3', transform=fig.transFigure)
ax2.text(0.2, 0.2, '#2_3', transform=fig.transFigure)

plt.show()

# %%
# Figure
# Axes - axis (x, y)

# %%
# Локаторы нужны для расположения (локации) рисок, а форматоры для текста рисок

grid = plt.GridSpec(1, 2)

ax1 = plt.subplot(grid[0, 0])
ax1.set_xscale('log')
ax1.set_xlim(1, 1000)
ax1.grid(True, which='major')

ax2 = plt.subplot(grid[0, 1])
ax2.set_yscale('log')
ax2.set(ylim=[1, 1000])
ax2.grid(True, which='both', axis='y') # major, minor, both

print(ax1.xaxis.get_major_locator())
print(ax1.xaxis.get_major_formatter())
print(ax1.xaxis.get_minor_locator())
print(ax1.xaxis.get_minor_formatter())

print(ax1.yaxis.get_major_locator())
print(ax1.yaxis.get_minor_formatter())
print(ax1.yaxis.get_major_formatter())
print(ax1.yaxis.get_minor_locator())

ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax2.xaxis.set_major_locator(plt.NullLocator())

plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces

faces = fetch_olivetti_faces().images

# %%
fig, ax = plt.subplots(7, 7)
fig.subplots_adjust(hspace=0, wspace=0)

for i in range(7):
    for j in range(7):
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        
        ax[i, j].imshow(faces[7*i + j], cmap='binary_r')

#plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

for a in ax.flat:
    a.xaxis.set_major_locator(plt.MaxNLocator(10)) # 10 делений
    a.yaxis.set_major_locator(plt.MaxNLocator(5))

plt.tight_layout()

plt.show()

# %%
def ff(value, tick_number):
    N = np.round(2 * value / np.pi)
    if N == 0:
        return 0
    elif N == 1:
        return r'$\frac{\pi}{2}$'
    elif N == 2:
        return r'$\pi$'
    elif N % 2 == 0:
        t = int(N // 2)
        return f"{t}" + r"$\pi$"
    else:
        return f"{int(N)}" + r"$\frac{\pi}{2}$"

# %%
x = np.linspace(0, 4 * np.pi, 1000)

fig, ax = plt.subplots()

ax.plot(x, np.sin(x), label='Sinus')
ax.plot(x, np.cos(x), label='Cosinus')

ax.grid(True)
ax.set_xlim(0, 4 * np.pi)

ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))
ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 4))

ax.xaxis.set_major_formatter(plt.FuncFormatter(ff))

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(8, 1, figsize=(6, 7)) # ширина = 6 дюймов, высота = 10 дюймов.

x = np.linspace(0, 20, 10)

for i in ax.flat:
    i.plot(x, x * 0 + 3)

ax[0].xaxis.set_major_locator(plt.NullLocator())
ax[1].xaxis.set_major_locator(plt.MultipleLocator(0.8))
ax[2].xaxis.set_major_locator(plt.FixedLocator([1, 3, 8, 9]))
ax[3].xaxis.set_major_locator(plt.LinearLocator(numticks=4))
ax[4].xaxis.set_major_locator(plt.IndexLocator(base=1.5, offset=0.3))
ax[5].xaxis.set_major_locator(plt.AutoLocator())
ax[6].xaxis.set_major_locator(plt.MaxNLocator(8))
ax[7].xaxis.set_major_locator(plt.LogLocator(base=3))

import matplotlib.ticker as mtick
ax[1].xaxis.set_major_formatter(plt.NullFormatter())
ax[2].xaxis.set_major_formatter(plt.FixedFormatter(['a', 'b', 'c', 'd']))
ax[3].xaxis.set_major_formatter(plt.FormatStrFormatter('%.2f $m^2$'))
ax[4].xaxis.set_major_formatter(mtick.PercentFormatter(xmax=20)) # x(current tick) / xmax * 100

plt.tight_layout()

plt.show()

# %%
x = np.random.randn(1000)

# 3 different ways with the same result 

#plt.style.use('mpl_style.txt')

#plt.figure(facecolor='#921212')
#plt.axes(facecolor='#adadad')

#plt.rc('figure', facecolor='#921212')
#plt.rc('axes', facecolor='#adadad')

plt.style.use('classic')

plt.hist(x, bins=10)

plt.show()

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fivethirtyeight', 'ggplot', 'grayscale', 'tableau10']

# %%
# Seaborn - высокоуровневая надстройка к Matplotlib
# Matplotlib работает через numpy, а Seaborn через DataFrame

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
cars = pd.read_csv('cars.csv.gz')
print(cars.head())
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage  engine   max_power  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74 bhp
# 1  Individual       Manual  Second Owner    21.14  1498.0  103.52 bhp
# 2  Individual       Manual   Third Owner    17.70  1497.0      78 bhp
# 3  Individual       Manual   First Owner    23.00  1396.0      90 bhp
# 4  Individual       Manual   First Owner    16.10  1298.0    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# ...

# %%
# Числовые данные
# парная диаграмма
sns.pairplot(data=cars, hue='transmission') # Он позволяет окрасить точки на всех графиках по значениям из указанного столбца

plt.show()

# %%
# Тепловая карта в Seaborn
'''
Тепловые карты (heatmaps) показывают плотность, интенсивность или распределение данных с помощью цвета. 
Проще говоря, они превращают скучные цифры в наглядную цветную картинку, где каждый оттенок имеет значение.
'''
# Out:
# '\nТепловые карты (heatmaps) показывают плотность, интенсивность или распределение данных с помощью цвета. \nПроще говоря, они превращают скучные цифры в наглядную цветную картинку, где каждый оттенок имеет значение.\n'

# %%
cars_corr = cars[['year', 'selling_price', 'seats', 'mileage']]

sns.heatmap(cars_corr.corr(), cmap='viridis', annot=True)

plt.show()

# %%
# Диаграмма рассеяния
sns.scatterplot(x='year', y='selling_price', data=cars, hue='fuel')

plt.show()

# %%
# Диаграмма рассеяния + лин.регрессия
sns.relplot(x='seats', y='mileage', data=cars, kind='scatter', col='fuel', col_wrap=2, hue='transmission') 

plt.show()

# %%
# Диаграмма рассеяния + лин.регрессия
sns.lmplot(x='seats', y='mileage', data=cars, hue='fuel', col='transmission', col_wrap=2)

plt.show()

# %%
# Линейный график
sns.lineplot(x='seats', y='mileage', data=cars, hue='fuel')
plt.show()

# %%
# Сводная диаграмма
sns.jointplot(x='year', y='selling_price', data=cars)

plt.show()

# %%
# Сводная диаграмма
# sns.jointplot(x='year', y='selling_price', data=cars, kind='kde')
sns.jointplot(x='year', y='selling_price', data=cars,    kind='reg', joint_kws={'line_kws': {'color': 'purple', 'linewidth': 3, 'linestyle': '--'}})

plt.show()

# %%
sns.jointplot(x='year', y='selling_price', data=cars, hue='transmission')

# %%
# Категории и числа
sns.barplot(x='fuel', y='selling_price', data=cars, estimator=np.mean, hue='transmission')

plt.show()

# %%
sns.catplot(x='fuel', y='selling_price', data=cars, hue='transmission', col='seller_type', col_wrap=2) # kind = 'bar' - will get the same graph like above one

plt.show()

# %%
sns.pointplot(x='fuel', y='selling_price', data=cars, estimator=np.mean, hue='transmission')
# Out:
# <Axes: xlabel='fuel', ylabel='selling_price'>

# %%
sns.boxplot(x='fuel', y='selling_price', data=cars, hue='transmission')
'''
Выбросы (outliers) — точки за пределами усов, отображаются отдельными маркерами (обычно кружками).
'''
plt.show()

# %%
'''
Скрипка (violin) показывает распределение
'''
sns.violinplot(x='fuel', y='selling_price', data=cars, hue='transmission')

plt.show()

# %%
# Можно совмещать
fig, ax = plt.subplots()
sns.violinplot(x='fuel', y='selling_price', data=cars, hue='transmission', ax=ax)
sns.stripplot(x='fuel', y='selling_price', data=cars, hue='transmission', ax=ax, dodge=True)

plt.show()
